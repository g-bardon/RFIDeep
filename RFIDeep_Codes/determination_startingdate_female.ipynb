# %%
import pandas as pd
from datetime import datetime, timedelta
import numpy as np
from matplotlib import pyplot as plt

# %%
df = pd.read_csv('detections_training_sex_breeding_dates.csv', sep = ";")

# Purpose: Make start_date and end_date columns a pandas timestamp datetime64

df['date'] = pd.to_datetime(df['date'], format="%Y-%m-%d %H:%M:%S")

df = df.replace("sea", 0) 
df = df.replace("colony", 1)

df = df.sort_values(by = ['rfid', 'date'])

print(df)
# Out:
#                              rfid                date  antenna
# 66655  A 00000 0 964 000000912030 2003-11-29 04:56:20        1
# 66656  A 00000 0 964 000000912030 2005-11-16 07:59:07        0
# 66657  A 00000 0 964 000000912030 2005-11-16 07:59:38        1
# 66658  A 00000 0 964 000000912030 2005-11-16 13:34:50        1
# 66659  A 00000 0 964 000000912030 2005-11-16 13:36:19        0
# ...                           ...                 ...      ...
# 35557     R 0000 0000000088473081 2015-01-08 17:06:41        0
# 35558     R 0000 0000000088473081 2015-01-11 06:12:55        0
# 35559     R 0000 0000000088473081 2015-01-11 06:12:58        1
# 35560     R 0000 0000000088473081 2015-02-10 07:04:03        1
# 35561     R 0000 0000000088473081 2015-02-10 07:04:14        0
#
# [293368 rows x 3 columns]

# %%
# Purpose: Bring in breeding data
import datetime as dt
breedingdata = pd.read_csv('training_dataset_breeding_dates.csv', sep = ",")

# only keeping male breeding cycles and put label 0
breedingdata = breedingdata.loc[(breedingdata["sex"] == "M")]
breedingdata = breedingdata[["rfid", "year", "sex", "start_date"]]
breedingdata = breedingdata.replace("M", 0)

pd.to_datetime(breedingdata['year'], format="%Y")

breedingdata['date'] = pd.to_datetime((breedingdata['year']-1).astype("str") + "-10-01", format="%Y-%m-%d")

print(breedingdata)

## Remove all years where detections are missing (at the beginning or at the end)
list_to_remove = []
for i in range(len(breedingdata)):
    rfid, date = breedingdata.iloc[i, [0,4]]
    if df.loc[(df["rfid"] == rfid) & (df["date"] <= date)].empty:
        list_to_remove.append(i)
    elif df.loc[(df["rfid"] == rfid) & (df["date"] >= date + pd.to_timedelta("487d"))].empty:
        list_to_remove.append(i)
breedingdata = breedingdata.drop(breedingdata.index[list_to_remove])

print(len(breedingdata))
# Out:
#                            rfid  year  sex           start_date       date
# 0    A 00000 0 964 000000912030  2017    0  2016-12-26 08:42:47 2016-10-01
# 3    A 00000 0 964 000000912194  2011    0  2010-12-19 09:32:17 2010-10-01
# 4    A 00000 0 964 000000912312  2018    0  2017-11-01 01:10:03 2017-10-01
# 5    A 00000 0 964 000000912379  2018    0  2017-12-17 18:36:45 2017-10-01
# 6    A 00000 0 964 000000912399  2018    0  2018-01-22 04:16:16 2017-10-01
# ..                          ...   ...  ...                  ...        ...
# 277     R 0000 0000000088471708  2015    0  2014-11-13 14:29:44 2014-10-01
# 278     R 0000 0000000088471730  2018    0  2017-11-07 11:09:01 2017-10-01
# 281     R 0000 0000000088472006  2018    0  2017-11-05 04:44:29 2017-10-01
# 284     R 0000 0000000088472884  2017    0  2016-12-14 18:52:30 2016-10-01
# 285     R 0000 0000000088473081  2014    0  2013-11-08 11:31:23 2013-10-01
#
# [160 rows x 5 columns]
# 157

# %%
### Missing detection correction algorithms ###

import datetime

class DetectionsCorrection():
    def __init__(self):
        pass
    def transition_fun(self, data):
        """
        :param data: list of the detections of the bird for the season
        :param bd: database
        :return: the list composed of the departure, time and arrival of the birds (binary, 0 or 1)
        """
        # Init
        x = []
        temp = []
        time_estimated = 600  # time we estimate for a penguin to get through a gate (10 mns)

        # Convert the datetime in s, if datetime object doesnt exist we take the nearest value
        for z in range(len(data)):
            if data[z][1] is not None:
                temp.append(int(round(data[z][1].timestamp())))

        transit = [[0] * 3 for _ in range(len(data))]

        for z in range(len(data) - 1):
            # if the bird is coming from sea (0) to earth (1)
            if (data[z][2] - data[z + 1][2]) < 0:
                transit[z][0] = 0
                transit[z][2] = 1

                # if the bird is coming from earth to sea
            elif (data[z][2] - data[z + 1][2]) > 0:
                transit[z][0] = 1
                transit[z][2] = 0

            elif (data[z][2] - data[z + 1][2]) == 0:
                # if the bird is coming from sea to sea
                if (data[z][2]) == 0:
                    transit[z][0] = 0
                    transit[z][2] = 0

                # if the bird is coming from earth to earth
                elif (data[z][2]) == 1:
                    transit[z][0] = 1
                    transit[z][2] = 1

            # if the time is short (0) or long (1)
            if (temp[z + 1] - temp[z]) <= time_estimated:
                transit[z][1] = 0
            else:
                transit[z][1] = 1

        return transit


    def binary_fun(self, vect):
        """
        :param vect: list of the transition
        :return: the list of 3bit coming from transition
        """
        sum = [[0] * 1 for _ in range(len(vect))]

        for i in range(len(vect)):
            sum[i] = vect[i][0] * 4 + vect[i][1] * 2 + vect[i][2]
        return sum

    def repair_missing_data(self, list_detec, data_list, rfid):
        gap = list_detec
        diff_gate = 1  # diff between gate 1 and gate 2

        comp = len(gap)
        index_of_transition = [i for i in range(comp)]  # here we register the index of the the transition in the data_list before removing the 0 and 5 transitions

        x = 0
        # Here we remove the short transition "terre-terre" and "mer-mer" because it corresponds to a double detection
        while x < comp:
            if gap[x] == 0 or gap[x] == 5:
                del gap[x]
                del index_of_transition[x]  ## for the transition gap[i], we have date and gate information in data_list[index_of_transition[i]]
                comp = comp - 1
                x = x - 1
            x = x + 1

        data_rebuild = [] # the detections that we add
        i=2
        while i < comp - 5 : #stop 2 detections before the end
            # 162
            if gap[i] == 6 and gap[i - 1] == 1 and gap[i + 1] == 2:
                gap[i] = 7
                gap.insert(i + 1, 4)
                data_rebuild.append(
                    [data_list[index_of_transition[i-comp] + 1][2] + diff_gate, rfid,
                     data_list[index_of_transition[i-comp] + 1][1] - datetime.timedelta(
                         milliseconds=3000)])
                comp = comp + 1

            # 163 we correct only the 6
            elif gap[i] == 6 and gap[i - 1] == 1 and gap[i + 1] == 3:
                gap[i] = 7
                gap.insert(i + 1, 4)

                data_rebuild.append(
                    [data_list[index_of_transition[i-comp] + 1][2] + diff_gate, rfid,
                     data_list[index_of_transition[i-comp] + 1][1] - datetime.timedelta(
                         milliseconds=3000)])
                comp = comp + 1

            # 234
            elif gap[i] == 3 and gap[i - 1] == 2 and gap[i + 1] == 4:
                gap[i] = 1
                gap.insert(i + 1, 7)
                data_rebuild.append(
                    [data_list[index_of_transition[i-comp]][2] + diff_gate, rfid,
                     data_list[index_of_transition[i-comp]][1] + datetime.timedelta(
                         milliseconds=3000)])
                comp = comp + 1

            # 236
            elif gap[i] == 3 and gap[i - 1] == 2 and gap[i + 1] == 6:
                gap[i] = 1
                gap.insert(i + 1, 7)
                gap[i+2] = 4
                gap.insert(i+3,2)

                data_rebuild.append(
                    [data_list[index_of_transition[i-comp]][2] + diff_gate, rfid,
                     data_list[index_of_transition[i-comp]][1] + datetime.timedelta(
                         milliseconds=3000)])
                data_rebuild.append(
                    [data_list[index_of_transition[i + 1-comp]][2] - diff_gate, rfid,
                     data_list[index_of_transition[i + 1-comp]][1] + datetime.timedelta(
                         milliseconds=3000)])
                comp = comp + 2

            # 436
            elif gap[i] == 3 and gap[i - 1] == 4 and gap[i + 1] == 6:
                gap[i] = 2
                gap.insert(i + 1, 1)

                data_rebuild.append(
                    [data_list[index_of_transition[i-comp] + 1][2] - diff_gate, rfid,
                     data_list[index_of_transition[i-comp] + 1][1] - datetime.timedelta(
                         milliseconds=3000)])
                comp = comp + 1

            # 437
            elif gap[i] == 3 and gap[i - 1] == 4 and gap[i + 1] == 7:
                gap[i] = 2
                gap.insert(i + 1, 1)

                data_rebuild.append(
                    [data_list[index_of_transition[i-comp] + 1][2] - diff_gate, rfid,
                     data_list[index_of_transition[i-comp] + 1][1] - datetime.timedelta(
                         milliseconds=3000)])
                comp = comp + 1

            # 761
            elif gap[i] == 6 and gap[i - 1] == 7 and gap[i + 1] == 1 :
                gap[i] = 4
                gap.insert(i + 1, 2)

                data_rebuild.append(
                    [data_list[index_of_transition[i-comp]][2] - diff_gate, rfid,
                     data_list[index_of_transition[i-comp]][1] + datetime.timedelta(
                         milliseconds=3000)])
                comp = comp + 1

            # 763
            elif gap[i] == 6 and gap[i - 1] == 7 and gap[i + 1] == 3:
                gap[i] = 4
                gap.insert(i + 1, 2)
                gap[i+2] = 1
                gap.insert(i+3, 7)

                data_rebuild.append(
                    [data_list[index_of_transition[i-comp]][2] - diff_gate, rfid,
                     data_list[index_of_transition[i-comp]][1] + datetime.timedelta(
                         milliseconds=3000)])
                data_rebuild.append(
                    [data_list[index_of_transition[i + 1 - comp]][2] + diff_gate, rfid,
                     data_list[index_of_transition[i + 1 - comp]][1] + datetime.timedelta(
                         milliseconds=3000)])
                comp = comp + 2

            # successives 2
            elif gap[i] == 2 and gap[i+1] == 2:
                j = 0
                while i+j+1 <= comp-3 and gap[i+j] == gap[i+j+1]: ## count number of successives 2 and stop if it is at the end of the transition list
                    j=j+1
                if i+j+1 == comp:
                    break # don't repair successives 2-2 if it is at the end

                if j % 2 == 0: ## j even number so odd numbers of successives 2 transitions
                    if gap[i - 1] == 6 and gap[i +j +1] == 1: # 6-2-2-2-1
                        gap[i-1] = 7
                        del gap[i:i+j+1]
                        gap[i:i] = [4,2,1,7] * (j//2) + [4,2]

                        data_rebuild.append(
                            [data_list[index_of_transition[i - 1 - comp] + 1][2] + diff_gate, rfid,
                             data_list[index_of_transition[i - 1 - comp] + 1][1] - datetime.timedelta(
                                 milliseconds=3000)])
                        for k in range(1, j // 2 + 1):
                            data_rebuild.append(
                                [data_list[index_of_transition[i + 2 * k -1- comp]][2] + diff_gate, rfid,
                                 data_list[index_of_transition[i + 2 * k -1- comp]][1] + datetime.timedelta(
                                     milliseconds=3000)])
                            data_rebuild.append(
                                [data_list[index_of_transition[i + 2 * k -1- comp] + 1][2] + diff_gate, rfid,
                                 data_list[index_of_transition[i + 2 * k -1- comp] + 1][1] - datetime.timedelta(
                                     milliseconds=3000)])
                        comp += 1 + j

                    elif gap[i-1] == 4 and gap[i +j +1] == 3: # 4-2-2-2-3
                        del gap[i+1:i+j+2]
                        gap[i+1:i+1] = [1,7,4,2] * (j//2) + [1,7]

                        for k in range(0,(j//2)):
                            data_rebuild.append(
                                [data_list[index_of_transition[i + k*2 +1- comp]][2] + diff_gate, rfid,
                                 data_list[index_of_transition[i + k*2 +1- comp]][1] + datetime.timedelta(
                                     milliseconds=3000)])
                            data_rebuild.append(
                                [data_list[index_of_transition[i + k*2 +1- comp]+1][2] + diff_gate, rfid,
                                 data_list[index_of_transition[i + k*2 +1- comp]+1][1] - datetime.timedelta(
                                     milliseconds=3000)])
                        data_rebuild.append(
                            [data_list[index_of_transition[i + j +1- comp]][2] + diff_gate, rfid,
                             data_list[index_of_transition[i + j +1- comp]][1] + datetime.timedelta(
                                 milliseconds=3000)])
                        comp += j + 1

                    elif gap[i-1] == 6 and gap[i +j +1] == 3: # 6-2-2-2-3
                        del gap[i-1:i+j+2]
                        gap[i-1:i-1] = [4,2,1,7]*((j//2)+1)+[4,2,1]

                        data_rebuild.append(
                            [data_list[index_of_transition[i-1-comp]][2] - diff_gate, rfid,
                             data_list[index_of_transition[i-1-comp]][1] + datetime.timedelta(
                                 milliseconds=3000)])
                        for k in range(0, j // 2 + 1):
                            data_rebuild.append(
                                [data_list[index_of_transition[i + 2 * k -comp]][2] + diff_gate, rfid,
                                 data_list[index_of_transition[i + 2 * k -comp]][1] + datetime.timedelta(
                                     milliseconds=3000)])
                            data_rebuild.append(
                                [data_list[index_of_transition[i + 2 * k -comp] + 1][2] + diff_gate, rfid,
                                 data_list[index_of_transition[i + 2 * k -comp] + 1][1] - datetime.timedelta(
                                     milliseconds=3000)])

                        data_rebuild.append(
                            [data_list[index_of_transition[i + j + 1 - comp] + 1][2] - diff_gate, rfid,
                             data_list[index_of_transition[i + j + 1 - comp] + 1][1] - datetime.timedelta(
                                 milliseconds=3000)])
                        comp += j + 4

                    elif gap[i-1] == 4 and gap[i +j +1] == 1: # 4-2-2-2-1
                        del gap[i+1:i + j + 1]
                        gap[i +1:i + 1] = [1,7,4,2] * (j//2)

                        for k in range(0,(j//2)):
                            data_rebuild.append(
                                [data_list[index_of_transition[i + k*2 +1- comp]][2] + diff_gate, rfid,
                                 data_list[index_of_transition[i + k*2 +1- comp]][1] + datetime.timedelta(
                                     milliseconds=3000)])
                            data_rebuild.append(
                                [data_list[index_of_transition[i + k*2 +1- comp]+1][2] + diff_gate, rfid,
                                 data_list[index_of_transition[i + k*2 +1- comp]+1][1] - datetime.timedelta(
                                     milliseconds=3000)])
                        comp += j

                else:## j odd number so even number of successives 2 transitions
                    if gap[i - 1] == 6 and gap[i + j + 1] == 1:
                        gap[i-1] = 4
                        del gap[i:i+j+1]
                        gap[i:i] = [2,1,7,4] * ((j//2)+1) + [2]

                        data_rebuild.append(
                            [data_list[index_of_transition[i-1-comp]][2] - diff_gate, rfid,
                             data_list[index_of_transition[i-1-comp]][1] + datetime.timedelta(
                                 milliseconds=3000)])
                        for k in range(0, (j + 1) // 2):
                            data_rebuild.append(
                                [data_list[index_of_transition[i + 2 * k - comp]][2] + diff_gate, rfid,
                                 data_list[index_of_transition[i + 2 * k - comp]][1] + datetime.timedelta(
                                     milliseconds=3000)])
                            data_rebuild.append(
                                [data_list[index_of_transition[i + 2 * k - comp] + 1][2] + diff_gate, rfid,
                                 data_list[index_of_transition[i + 2 * k - comp] + 1][1] - datetime.timedelta(
                                     milliseconds=3000)])
                        comp += 2 + j


                    elif gap[i - 1] == 4 and gap[i + j + 1] == 3 and gap[i + j + 2] != 4:
                        del gap[i+1:i+j+2]
                        gap[i+1:i+1] = [1,7,4,2]*((j//2)+1)+[1]

                        for k in range((j+1)//2):
                            data_rebuild.append(
                                [data_list[index_of_transition[i + k * 2 + 1 - comp]][2] + diff_gate, rfid,
                                 data_list[index_of_transition[i + k * 2 + 1 - comp]][1] + datetime.timedelta(
                                     milliseconds=3000)])
                            data_rebuild.append(
                                [data_list[index_of_transition[i + k * 2 + 1 - comp] + 1][2] + diff_gate, rfid,
                                 data_list[index_of_transition[i + k * 2 + 1 - comp] + 1][1] - datetime.timedelta(
                                     milliseconds=3000)])
                        data_rebuild.append(
                            [data_list[index_of_transition[i + j + 1 - comp]+1][2] - diff_gate, rfid,
                             data_list[index_of_transition[i + j + 1 - comp]+1][1] - datetime.timedelta(
                                 milliseconds=3000)])

                        comp += j + 2

                    elif gap[i - 1] == 6 and gap[i + j + 1] == 3:
                        # normally always a 7 before as already corrected
                        del gap[i-1:i+j+2]
                        gap[i-1:i-1] = [4,2,1,7] * ((j//2)+2)

                        data_rebuild.append(
                            [data_list[index_of_transition[i-1-comp]][2] - diff_gate, rfid,
                             data_list[index_of_transition[i-1-comp]][1] + datetime.timedelta(
                                 milliseconds=3000)])
                        for k in range(0, (j + 1) // 2):
                            data_rebuild.append(
                                [data_list[index_of_transition[i + 2 * k-comp]][2] + diff_gate, rfid,
                                 data_list[index_of_transition[i + 2 * k-comp]][1] + datetime.timedelta(
                                     milliseconds=3000)])
                            data_rebuild.append(
                                [data_list[index_of_transition[i + 2 * k-comp] + 1][2] + diff_gate, rfid,
                                 data_list[index_of_transition[i + 2 * k-comp] + 1][1] - datetime.timedelta(
                                     milliseconds=3000)])

                        data_rebuild.append(
                            [data_list[index_of_transition[i + j + 1-comp]][2] + diff_gate, rfid,
                             data_list[index_of_transition[i + j + 1-comp]][1] + datetime.timedelta(
                                 milliseconds=3000)])

                        comp += j+3

                    ## we not repair if it is 4-2-2-1 because we don't know what transition is false

                # successives 7
            elif gap[i] == 7 and gap[i + 1] == 7:
                j = 0
                while i + j + 1 <= comp-3 and gap[i + j] == gap[i + j + 1] :  ## count number of successives 7 and stop if it is at the end of the transition list
                    j = j + 1
                if i+j+1 == comp:
                    break # don't repair successives 7-7 if it is at the end

                if j % 2 == 0:  ## j even number so odd numbers of successives 2 transitions
                    if gap[i - 1] == 3 and gap[i + j + 1] == 4:  # 3-7-7-7-4
                        gap[i - 1] = 2
                        del gap[i:i + j + 1]
                        gap[i:i] = [1, 7, 4, 2] * (j // 2) + [1, 7]

                        data_rebuild.append(
                            [data_list[index_of_transition[i - 1 - comp] + 1][2] - diff_gate, rfid,
                                data_list[index_of_transition[i - 1 - comp] + 1][1] - datetime.timedelta(
                                    milliseconds=3000)])
                        for k in range(1, j // 2 + 1):
                            data_rebuild.append(
                                        [data_list[index_of_transition[i + 2 * k - 1 - comp]][2] - diff_gate, rfid,
                                         data_list[index_of_transition[i + 2 * k - 1 - comp]][1] + datetime.timedelta(
                                             milliseconds=3000)])
                            data_rebuild.append(
                                        [data_list[index_of_transition[i + 2 * k - 1 - comp] + 1][2] - diff_gate,
                                         rfid,
                                         data_list[index_of_transition[i + 2 * k - 1 - comp] + 1][
                                             1] - datetime.timedelta(
                                             milliseconds=3000)])
                        comp += 1 + j

                    elif gap[i - 1] == 1 and gap[i + j + 1] == 6:  # 1-7-7-7-6
                        del gap[i + 1:i + j + 2]
                        gap[i + 1:i + 1] = [4, 2, 1, 7] * (j // 2) + [4, 2]

                        for k in range(0, (j // 2)):
                            data_rebuild.append(
                                        [data_list[index_of_transition[i + k * 2 + 1 - comp]][2] - diff_gate, rfid,
                                         data_list[index_of_transition[i + k * 2 + 1 - comp]][1] + datetime.timedelta(
                                             milliseconds=3000)])
                            data_rebuild.append(
                                        [data_list[index_of_transition[i + k * 2 + 1 - comp] + 1][2] - diff_gate,
                                         rfid,
                                         data_list[index_of_transition[i + k * 2 + 1 - comp] + 1][
                                             1] - datetime.timedelta(
                                             milliseconds=3000)])
                        data_rebuild.append(
                                    [data_list[index_of_transition[i + j + 1 - comp]][2] - diff_gate, rfid,
                                     data_list[index_of_transition[i + j + 1 - comp]][1] + datetime.timedelta(
                                         milliseconds=3000)])
                        comp += j + 1

                    elif gap[i - 1] == 3 and gap[i + j + 1] == 6:  # 3-7-7-7-6
                        del gap[i - 1:i + j + 2]
                        gap[i - 1:i - 1] = [1, 7, 4, 2] * ((j // 2) + 1) + [1, 7, 4]

                        data_rebuild.append(
                                    [data_list[index_of_transition[i - 1 - comp]][2] + diff_gate, rfid,
                                     data_list[index_of_transition[i - 1 - comp]][1] + datetime.timedelta(
                                         milliseconds=3000)])
                        for k in range(0, j // 2 + 1):
                            data_rebuild.append(
                                        [data_list[index_of_transition[i + 2 * k - comp]][2] - diff_gate, rfid,
                                         data_list[index_of_transition[i + 2 * k - comp]][1] + datetime.timedelta(
                                             milliseconds=3000)])
                            data_rebuild.append(
                                        [data_list[index_of_transition[i + 2 * k - comp] + 1][2] - diff_gate, rfid,
                                         data_list[index_of_transition[i + 2 * k - comp] + 1][1] - datetime.timedelta(
                                             milliseconds=3000)])

                        data_rebuild.append(
                                    [data_list[index_of_transition[i + j + 1 - comp] + 1][2] + diff_gate, rfid,
                                     data_list[index_of_transition[i + j + 1 - comp] + 1][1] - datetime.timedelta(
                                         milliseconds=3000)])
                        comp += j + 4

                    elif gap[i - 1] == 1 and gap[i + j + 1] == 4:  # 1-7-7-7-4
                        del gap[i + 1:i + j + 1]
                        gap[i + 1:i + 1] = [4, 2, 1, 7] * (j // 2)

                        for k in range(0, (j // 2)):
                            data_rebuild.append(
                                        [data_list[index_of_transition[i + k * 2 + 1 - comp]][2] - diff_gate, rfid,
                                         data_list[index_of_transition[i + k * 2 + 1 - comp]][1] + datetime.timedelta(
                                             milliseconds=3000)])
                            data_rebuild.append(
                                        [data_list[index_of_transition[i + k * 2 + 1 - comp] + 1][2] - diff_gate,
                                         rfid,
                                         data_list[index_of_transition[i + k * 2 + 1 - comp] + 1][
                                             1] - datetime.timedelta(
                                             milliseconds=3000)])
                        comp += j

                else:  ## j odd number so even number of successives 2 transitions
                    if gap[i - 1] == 3 and gap[i + j + 1] == 7:
                        gap[i - 1] = 1
                        del gap[i:i + j + 1]
                        gap[i:i] = [7, 4, 2, 1] * ((j // 2) + 1) + [7]

                        data_rebuild.append(
                                    [data_list[index_of_transition[i - 1 - comp]][2] + diff_gate, rfid,
                                     data_list[index_of_transition[i - 1 - comp]][1] + datetime.timedelta(
                                         milliseconds=3000)])
                        for k in range(0, (j + 1) // 2):
                            data_rebuild.append(
                                        [data_list[index_of_transition[i + 2 * k - comp]][2] - diff_gate, rfid,
                                         data_list[index_of_transition[i + 2 * k - comp]][1] + datetime.timedelta(
                                             milliseconds=3000)])
                            data_rebuild.append(
                                        [data_list[index_of_transition[i + 2 * k - comp] + 1][2] - diff_gate, rfid,
                                         data_list[index_of_transition[i + 2 * k - comp] + 1][1] - datetime.timedelta(
                                             milliseconds=3000)])
                        comp += 2 + j


                    elif gap[i - 1] == 1 and gap[i + j + 1] == 6 and gap[i + j + 1] != 1:
                        del gap[i+1:i + j + 2]
                        gap[i + 1:i + 1] = [4, 2, 1, 7] * ((j // 2) + 1) + [4]

                        for k in range((j + 1) // 2):
                            data_rebuild.append(
                                        [data_list[index_of_transition[i + k * 2 + 1 - comp]][2] - diff_gate, rfid,
                                         data_list[index_of_transition[i + k * 2 + 1 - comp]][1] + datetime.timedelta(
                                             milliseconds=3000)])
                            data_rebuild.append(
                                        [data_list[index_of_transition[i + k * 2 + 1 - comp] + 1][2] - diff_gate,
                                         rfid,
                                         data_list[index_of_transition[i + k * 2 + 1 - comp] + 1][
                                             1] - datetime.timedelta(
                                             milliseconds=3000)])
                        data_rebuild.append(
                                    [data_list[index_of_transition[i + j + 1 - comp] + 1][2] + diff_gate, rfid,
                                     data_list[index_of_transition[i + j + 1 - comp] + 1][1] - datetime.timedelta(
                                         milliseconds=3000)])

                        comp += j + 2

                    elif gap[i - 1] == 3 and gap[i + j + 1] == 6:
                                # normally always a 2 before as already corrected
                        del gap[i - 1:i + j + 2]
                        gap[i - 1:i - 1] = [1, 7, 4, 2] * ((j // 2) + 2)

                        data_rebuild.append(
                                    [data_list[index_of_transition[i - 1 - comp]][2] + diff_gate, rfid,
                                     data_list[index_of_transition[i - 1 - comp]][1] + datetime.timedelta(
                                         milliseconds=3000)])
                        for k in range(0, (j + 1) // 2):
                            data_rebuild.append(
                                        [data_list[index_of_transition[i + 2 * k - comp]][2] - diff_gate, rfid,
                                         data_list[index_of_transition[i + 2 * k - comp]][1] + datetime.timedelta(
                                             milliseconds=3000)])
                            data_rebuild.append(
                                        [data_list[index_of_transition[i + 2 * k - comp] + 1][2] - diff_gate, rfid,
                                         data_list[index_of_transition[i + 2 * k - comp] + 1][1] - datetime.timedelta(
                                             milliseconds=3000)])

                        data_rebuild.append(
                                    [data_list[index_of_transition[i + j + 1 - comp]][2] - diff_gate, rfid,
                                     data_list[index_of_transition[i + j + 1 - comp]][1] + datetime.timedelta(
                                         milliseconds=3000)])

                        comp += j + 3

                            ## we not repair if it is 4-2-2-1 because we don't know what transition is false
            i = i+1

        if len(gap) != comp:
            print("Error")
        return data_rebuild

    def fill_gaps(self, rfid, detections):
        """
        :param rfid: rfid is a list define in the main file
        :return: dataframe of the gaps filled (4 row : antenne_id, RFID, date_arrivee, type)
        """

        data_return = []
        df = pd.DataFrame()
        
        if detections is not None:
            transition = self.transition_fun(detections)
            binary = self.binary_fun(transition)
            data_return = self.repair_missing_data(binary, detections, rfid)

        if data_return:
            data_return_sort = sorted(data_return, key=lambda colonnes: colonnes[2])
            data_return_inv = list(map(list, zip(*data_return_sort)))
            df = pd.DataFrame({'rfid': data_return_inv[1]})
            df['date'] = data_return_inv[2]
            df['antenna'] = data_return_inv[0]

        return df

# %%
### DATA GENERATOR ALGORITHM : DATA TREATMENT ALGORITHMS RUN AT EACH ITERATION ###

import numpy as np
from tensorflow import keras
import datetime
from datetime import timedelta
import random
import copy

class DataGenerator_penguins(keras.utils.Sequence, DetectionsCorrection):
    def __init__(self, breeding_dataframe, detection_dataframe):
        'Initialization'
        self.breeding_df = breeding_dataframe
        self.detection_df = detection_dataframe
        self.shuffle = True
        self.remove_detection_rate = 0.10 ### Rate of removed detections for data augmentation
        self.pengid_list = self.breeding_df['rfid'].unique().tolist()
        
    def __len__(self):
        return 1
    
    def on_epoch_end(self):
        pass
    
    def __getitem__(self,index):
        'Generate one batch of data'
        df = copy.copy(self.detection_df)
#         Remove some detections and correct it with the correction algorithm
        df = df.loc[random.sample(range(len(df)), int(len(df)*(1-self.remove_detection_rate))),:]  #removing 10% of every detections
        df = df.sort_values(by = ['rfid', 'date'])
        for i in self.pengid_list:
            df_correct_id = df.loc[df['rfid'] == i,:]
            df_correct_id = list(df_correct_id.itertuples(index=False, name=None))
            dc = DetectionsCorrection()
            correction = dc.fill_gaps(rfid=i, detections = df_correct_id)
            df = pd.concat([df, correction])
            
        detections_corrected = df.sort_values(by = ['rfid', 'date'])
        
        ## Change the starting date to create the wrong cases at each epoch
        breedingdata_modified = self.change_starting_date_bis(self.breeding_df)
            
        ## original cycles beginning at the right date
        X_train, y_train = self.creation_dataset(self.breeding_df, detections_corrected)
        
        ## added modified cycles that don't begin at the good date with label 1
        X_train_mod, _ = self.creation_dataset(breedingdata_modified, detections_corrected)
        y_train_mod = np.array([1]*len(X_train_mod))
        
        X_train = np.concatenate((X_train, X_train_mod))
        y_train = np.concatenate((y_train, y_train_mod))
        return X_train, y_train

            
    def get_Val(self, breeding_data, detections):
        'Used to generate the validation data into the right format'
        ## Change the starting date to create the wrong cases at each epoch
        breedingdata_modified = self.change_starting_date_bis(breeding_data)
        
        ## original cycles beginning at the right date
        X_test, y_test = self.creation_dataset(breeding_data, detections)
        
        ## added modified cycles that don't begin at the good date
        X_test_mod, _ = self.creation_dataset(breedingdata_modified, detections)
        y_test_mod = np.array([1]*len(X_test_mod))
        
        X_test = np.concatenate((X_test, X_test_mod))
        y_test = np.concatenate((y_test, y_test_mod))
        return X_test, y_test

    def creation_dataset(self, breedingdata, detections):
        breeding_data = copy.copy(breedingdata)
        df = detections
        merged_df = pd.DataFrame()
        for i in range(len(breeding_data)):
            rfid, year, sex, starting_date, date = breedingdata.iloc[i]
            temp_df = df.loc[(df["rfid"] == rfid) & (df["date"] >= date) & (df["date"] <= date + pd.to_timedelta("487d"))]
            temp_df.insert(loc=1,column='year',value=year)
            temp_df.insert(loc=2,column='sex',value=sex)
            temp_df.insert(loc=3,column='starting_date',value=starting_date)
            merged_df = pd.concat([merged_df, temp_df])

        out = []
        out2 = []
        out3=[]
        starting_index = []
        for start_year in range(1998, 2020):
                start_date = datetime.datetime(year=start_year-1, month=9, day=30)
                end_date = start_date + timedelta(days=487)
                dRange = pd.date_range(start=start_date, end=end_date, freq="12H")

                    # perform the grid search on time/rfid values
                values = merged_df[merged_df["year"] == start_year].groupby([pd.Grouper(key="date", freq="12H"), "rfid"])["antenna"].last().unstack().reindex(dRange).fillna(method="ffill").fillna(False).astype(int).values
                    # look for the corresponding breeding labels for this season
                values_detect_number = merged_df[merged_df["year"] == start_year].groupby([pd.Grouper(key="date", freq="12H"), "rfid"])["antenna"].size().unstack().reindex(dRange).fillna(value=0).astype(int).values
                starting_date = merged_df[merged_df["year"] == start_year].groupby(["rfid"])["starting_date"].last()
                labels = merged_df[merged_df["year"] == start_year].groupby(["rfid"])["sex"].last()
                for i in range(len(starting_date)):
                    starting_index.append(np.where(pd.Timestamp(starting_date[i]).floor("12H") == dRange)[0][0])
                out.extend(values.T)
                out3.extend(values_detect_number.T)
                out2.extend(labels)
        values = out
        values_shift = [[0] for x in range(len(values))]
        values_detection_shift = [[0] for x in range(len(values))]
        final_value = [[0] for x in range(len(values))]
        val = [[0,0] for x in range(180)]
        for i in range(len(values)):
            values_shift[i] = values[i][(starting_index[i]-30):(starting_index[i]+150)]
            values_detection_shift[i] = out3[i][(starting_index[i]-30):(starting_index[i]+150)]
            for j in range(180):
                val[j] = [values_shift[i][j],values_detection_shift[i][j]]
            final_value[i]= np.array(val)
        return np.array(final_value), np.array(out2)

    def change_starting_date_bis(self, breeding_data):
            breedingdata_modified = copy.copy(breeding_data)
            breedingdata_modified.reset_index(inplace=True, drop=True)
            for i in range(len(breedingdata_modified)):
                year_cycle = breedingdata_modified["year"].iloc[i]
                start_date = datetime.datetime(year=year_cycle-1, month=10, day=20)
                end_date = datetime.datetime(year=year_cycle, month=5, day=31)
                dRange = pd.date_range(start=start_date, end=end_date, freq="12H")
                date_to_remove = pd.to_datetime(breedingdata_modified["start_date"].iloc[i]).floor("12H")
                
                ## Take a date at least 3 days away from the original date
                dRange = dRange[(dRange < date_to_remove - datetime.timedelta(days=3)) | (dRange > date_to_remove + datetime.timedelta(days=3))]
                breedingdata_modified.loc[i, "start_date"] = pd.Timestamp(random.sample(list(dRange), 1)[0])
            return(breedingdata_modified)

# %%
### BUILDING OF CNN MODEL ### 
from tensorflow.keras.wrappers.scikit_learn import KerasClassifier
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Activation,MaxPooling1D, MaxPooling2D, Dropout, Flatten, Reshape, LSTM, Embedding, AveragePooling1D
from tensorflow.keras.layers import Dense, Conv1D, SimpleRNN, GRU
from tensorflow.keras.callbacks import ModelCheckpoint

model = Sequential()

# CNN LAYERS
model.add(Conv1D(filters=128, kernel_size=20, activation="relu", padding='same', input_shape=(180,2)))
model.add(AveragePooling1D(pool_size=2))
model.add(Dropout(0.5))
model.add(Conv1D(filters=32, kernel_size=10,activation="relu", padding='same', input_shape=(180,2))) 
model.add(AveragePooling1D(pool_size=2))
model.add(Dropout(0.5))
model.add(Conv1D(filters=16, kernel_size=5,activation="relu", padding='same'))
model.add(MaxPooling1D(pool_size=2))
model.add(AveragePooling1D(0.5))
model.add(Flatten())

model.add(Dense(500, activation = 'relu'))
model.add(Dense(250, activation = 'relu'))
model.add(Dense(100, activation = 'relu'))

model.add(Dense(2, activation = 'softmax'))
# COMPILATION
model.compile(loss = 'sparse_categorical_crossentropy',optimizer = 'adam', metrics = ['accuracy'])

# %%
### MODEL FITTING ###

import numpy as np
import datetime
from tensorflow import device
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential

# Datasets
training_data, testing_data = train_test_split(breedingdata, test_size=0.2)

# Call of data generator
DG = DataGenerator_penguins(training_data, df)

y_test = DG.get_Val(testing_data, df)

# Train model on dataset
with device("/device:GPU:0"):
    model.fit(DG, validation_data=y_test,
                    use_multiprocessing=False,
                    workers=6, epochs = 200, verbose=2)
# Out:
# Epoch 1/200
# 1/1 - 9s - loss: 0.7073 - accuracy: 0.4920 - val_loss: 0.6843 - val_accuracy: 0.5000 - 9s/epoch - 9s/step
# Epoch 2/200
# 1/1 - 15s - loss: 0.7039 - accuracy: 0.5040 - val_loss: 0.6673 - val_accuracy: 0.7812 - 15s/epoch - 15s/step
# Epoch 3/200
# 1/1 - 15s - loss: 0.6558 - accuracy: 0.6560 - val_loss: 0.6539 - val_accuracy: 0.5156 - 15s/epoch - 15s/step
# Epoch 4/200
# 1/1 - 14s - loss: 0.6544 - accuracy: 0.5680 - val_loss: 0.6272 - val_accuracy: 0.6562 - 14s/epoch - 14s/step
# Epoch 5/200
# 1/1 - 14s - loss: 0.6219 - accuracy: 0.6560 - val_loss: 0.5811 - val_accuracy: 0.8906 - 14s/epoch - 14s/step
# Epoch 6/200
# 1/1 - 16s - loss: 0.5822 - accuracy: 0.7280 - val_loss: 0.5220 - val_accuracy: 0.9531 - 16s/epoch - 16s/step
# Epoch 7/200
# 1/1 - 16s - loss: 0.5261 - accuracy: 0.7640 - val_loss: 0.4579 - val_accuracy: 0.8750 - 16s/epoch - 16s/step
# Epoch 8/200
# 1/1 - 15s - loss: 0.4689 - accuracy: 0.8120 - val_loss: 0.4057 - val_accuracy: 0.8438 - 15s/epoch - 15s/step
# Epoch 9/200
# 1/1 - 14s - loss: 0.4274 - accuracy: 0.8080 - val_loss: 0.3124 - val_accuracy: 0.9062 - 14s/epoch - 14s/step
# Epoch 10/200
# 1/1 - 15s - loss: 0.3177 - accuracy: 0.8640 - val_loss: 0.2378 - val_accuracy: 0.9531 - 15s/epoch - 15s/step
# Epoch 11/200
# 1/1 - 14s - loss: 0.3890 - accuracy: 0.8520 - val_loss: 0.2094 - val_accuracy: 0.9375 - 14s/epoch - 14s/step
# Epoch 12/200
# 1/1 - 15s - loss: 0.3260 - accuracy: 0.8840 - val_loss: 0.2486 - val_accuracy: 0.9062 - 15s/epoch - 15s/step
# Epoch 13/200
# 1/1 - 14s - loss: 0.2785 - accuracy: 0.8960 - val_loss: 0.2416 - val_accuracy: 0.9219 - 14s/epoch - 14s/step
# Epoch 14/200
# 1/1 - 14s - loss: 0.2998 - accuracy: 0.8880 - val_loss: 0.1719 - val_accuracy: 0.9375 - 14s/epoch - 14s/step
# Epoch 15/200
# 1/1 - 15s - loss: 0.2002 - accuracy: 0.9120 - val_loss: 0.1354 - val_accuracy: 0.9531 - 15s/epoch - 15s/step
# Epoch 16/200
# 1/1 - 15s - loss: 0.2735 - accuracy: 0.8960 - val_loss: 0.1455 - val_accuracy: 0.9375 - 15s/epoch - 15s/step
# Epoch 17/200
# 1/1 - 15s - loss: 0.3269 - accuracy: 0.9240 - val_loss: 0.1654 - val_accuracy: 0.9375 - 15s/epoch - 15s/step
# Epoch 18/200
# 1/1 - 15s - loss: 0.1033 - accuracy: 0.9760 - val_loss: 0.1716 - val_accuracy: 0.9375 - 15s/epoch - 15s/step
# Epoch 19/200
# 1/1 - 15s - loss: 0.3473 - accuracy: 0.8480 - val_loss: 0.1363 - val_accuracy: 0.9531 - 15s/epoch - 15s/step
# Epoch 20/200
# 1/1 - 15s - loss: 0.1772 - accuracy: 0.9400 - val_loss: 0.1294 - val_accuracy: 0.9531 - 15s/epoch - 15s/step
# Epoch 21/200
# 1/1 - 15s - loss: 0.2780 - accuracy: 0.8920 - val_loss: 0.1393 - val_accuracy: 0.9531 - 15s/epoch - 15s/step
# Epoch 22/200
# 1/1 - 15s - loss: 0.2193 - accuracy: 0.9360 - val_loss: 0.1571 - val_accuracy: 0.9531 - 15s/epoch - 15s/step
# Epoch 23/200
# 1/1 - 15s - loss: 0.2281 - accuracy: 0.9120 - val_loss: 0.1728 - val_accuracy: 0.9531 - 15s/epoch - 15s/step
# Epoch 24/200
# 1/1 - 15s - loss: 0.2102 - accuracy: 0.9160 - val_loss: 0.1781 - val_accuracy: 0.9531 - 15s/epoch - 15s/step
# Epoch 25/200
# 1/1 - 15s - loss: 0.2224 - accuracy: 0.9320 - val_loss: 0.1714 - val_accuracy: 0.9531 - 15s/epoch - 15s/step
# Epoch 26/200
# 1/1 - 14s - loss: 0.1657 - accuracy: 0.9400 - val_loss: 0.1580 - val_accuracy: 0.9531 - 14s/epoch - 14s/step
# Epoch 27/200
# 1/1 - 14s - loss: 0.1571 - accuracy: 0.9360 - val_loss: 0.1467 - val_accuracy: 0.9531 - 14s/epoch - 14s/step
# Epoch 28/200
# 1/1 - 14s - loss: 0.1394 - accuracy: 0.9560 - val_loss: 0.1362 - val_accuracy: 0.9531 - 14s/epoch - 14s/step
# Epoch 29/200
# 1/1 - 14s - loss: 0.2276 - accuracy: 0.9000 - val_loss: 0.1295 - val_accuracy: 0.9531 - 14s/epoch - 14s/step
# Epoch 30/200
# 1/1 - 14s - loss: 0.1142 - accuracy: 0.9600 - val_loss: 0.1251 - val_accuracy: 0.9531 - 14s/epoch - 14s/step
# Epoch 31/200
# 1/1 - 14s - loss: 0.1788 - accuracy: 0.9280 - val_loss: 0.1211 - val_accuracy: 0.9531 - 14s/epoch - 14s/step
# Epoch 32/200
# 1/1 - 14s - loss: 0.1646 - accuracy: 0.9240 - val_loss: 0.1094 - val_accuracy: 0.9531 - 14s/epoch - 14s/step
# Epoch 33/200
# 1/1 - 15s - loss: 0.1448 - accuracy: 0.9560 - val_loss: 0.1030 - val_accuracy: 0.9531 - 15s/epoch - 15s/step
# Epoch 34/200
# 1/1 - 16s - loss: 0.1482 - accuracy: 0.9560 - val_loss: 0.0944 - val_accuracy: 0.9531 - 16s/epoch - 16s/step
# Epoch 35/200
# 1/1 - 15s - loss: 0.1388 - accuracy: 0.9520 - val_loss: 0.0859 - val_accuracy: 0.9531 - 15s/epoch - 15s/step
# Epoch 36/200
# 1/1 - 15s - loss: 0.2266 - accuracy: 0.9200 - val_loss: 0.0802 - val_accuracy: 0.9688 - 15s/epoch - 15s/step
# Epoch 37/200
# 1/1 - 14s - loss: 0.1188 - accuracy: 0.9640 - val_loss: 0.0781 - val_accuracy: 0.9688 - 14s/epoch - 14s/step
# Epoch 38/200
# 1/1 - 15s - loss: 0.1590 - accuracy: 0.9520 - val_loss: 0.0771 - val_accuracy: 0.9688 - 15s/epoch - 15s/step
# Epoch 39/200
# 1/1 - 15s - loss: 0.0928 - accuracy: 0.9640 - val_loss: 0.0755 - val_accuracy: 0.9688 - 15s/epoch - 15s/step
# Epoch 40/200
# 1/1 - 15s - loss: 0.1056 - accuracy: 0.9720 - val_loss: 0.0739 - val_accuracy: 0.9688 - 15s/epoch - 15s/step
# Epoch 41/200
# 1/1 - 15s - loss: 0.1538 - accuracy: 0.9480 - val_loss: 0.0775 - val_accuracy: 0.9531 - 15s/epoch - 15s/step
# Epoch 42/200
# 1/1 - 14s - loss: 0.1500 - accuracy: 0.9480 - val_loss: 0.0821 - val_accuracy: 0.9531 - 14s/epoch - 14s/step
# Epoch 43/200
# 1/1 - 15s - loss: 0.0999 - accuracy: 0.9560 - val_loss: 0.0865 - val_accuracy: 0.9531 - 15s/epoch - 15s/step
# Epoch 44/200
# 1/1 - 15s - loss: 0.1507 - accuracy: 0.9440 - val_loss: 0.0872 - val_accuracy: 0.9531 - 15s/epoch - 15s/step
# Epoch 45/200
# 1/1 - 15s - loss: 0.1253 - accuracy: 0.9560 - val_loss: 0.0838 - val_accuracy: 0.9531 - 15s/epoch - 15s/step
# Epoch 46/200
# 1/1 - 15s - loss: 0.1360 - accuracy: 0.9400 - val_loss: 0.0772 - val_accuracy: 0.9531 - 15s/epoch - 15s/step
# Epoch 47/200
# 1/1 - 15s - loss: 0.1340 - accuracy: 0.9400 - val_loss: 0.0718 - val_accuracy: 0.9688 - 15s/epoch - 15s/step
# Epoch 48/200
# 1/1 - 15s - loss: 0.0953 - accuracy: 0.9720 - val_loss: 0.0687 - val_accuracy: 0.9688 - 15s/epoch - 15s/step
# Epoch 49/200
# 1/1 - 15s - loss: 0.1192 - accuracy: 0.9600 - val_loss: 0.0680 - val_accuracy: 0.9688 - 15s/epoch - 15s/step
# Epoch 50/200
# 1/1 - 14s - loss: 0.1503 - accuracy: 0.9400 - val_loss: 0.0672 - val_accuracy: 1.0000 - 14s/epoch - 14s/step
# Epoch 51/200
# 1/1 - 14s - loss: 0.1080 - accuracy: 0.9560 - val_loss: 0.0681 - val_accuracy: 0.9688 - 14s/epoch - 14s/step
# Epoch 52/200
# 1/1 - 13s - loss: 0.1362 - accuracy: 0.9600 - val_loss: 0.0724 - val_accuracy: 0.9531 - 13s/epoch - 13s/step
# Epoch 53/200
# 1/1 - 7s - loss: 0.1178 - accuracy: 0.9600 - val_loss: 0.0841 - val_accuracy: 0.9531 - 7s/epoch - 7s/step
# Epoch 54/200
# 1/1 - 13s - loss: 0.1489 - accuracy: 0.9400 - val_loss: 0.0918 - val_accuracy: 0.9531 - 13s/epoch - 13s/step
# Epoch 55/200
# 1/1 - 13s - loss: 0.1826 - accuracy: 0.9440 - val_loss: 0.0855 - val_accuracy: 0.9531 - 13s/epoch - 13s/step
# Epoch 56/200
# 1/1 - 13s - loss: 0.1436 - accuracy: 0.9600 - val_loss: 0.0732 - val_accuracy: 0.9688 - 13s/epoch - 13s/step
# Epoch 57/200
# 1/1 - 13s - loss: 0.1208 - accuracy: 0.9520 - val_loss: 0.0651 - val_accuracy: 0.9844 - 13s/epoch - 13s/step
# Epoch 58/200
# 1/1 - 13s - loss: 0.1102 - accuracy: 0.9560 - val_loss: 0.0619 - val_accuracy: 1.0000 - 13s/epoch - 13s/step
# Epoch 59/200
# 1/1 - 13s - loss: 0.1435 - accuracy: 0.9520 - val_loss: 0.0616 - val_accuracy: 1.0000 - 13s/epoch - 13s/step
# Epoch 60/200
# 1/1 - 13s - loss: 0.1580 - accuracy: 0.9440 - val_loss: 0.0589 - val_accuracy: 1.0000 - 13s/epoch - 13s/step
# Epoch 61/200
# 1/1 - 13s - loss: 0.1174 - accuracy: 0.9680 - val_loss: 0.0587 - val_accuracy: 1.0000 - 13s/epoch - 13s/step
# Epoch 62/200
# 1/1 - 14s - loss: 0.1219 - accuracy: 0.9480 - val_loss: 0.0644 - val_accuracy: 0.9844 - 14s/epoch - 14s/step
# Epoch 63/200
# 1/1 - 13s - loss: 0.0658 - accuracy: 0.9720 - val_loss: 0.0741 - val_accuracy: 0.9531 - 13s/epoch - 13s/step
# Epoch 64/200
# 1/1 - 13s - loss: 0.2024 - accuracy: 0.9280 - val_loss: 0.0711 - val_accuracy: 0.9531 - 13s/epoch - 13s/step
# Epoch 65/200
# 1/1 - 13s - loss: 0.1088 - accuracy: 0.9520 - val_loss: 0.0687 - val_accuracy: 0.9688 - 13s/epoch - 13s/step
# Epoch 66/200
# 1/1 - 13s - loss: 0.1290 - accuracy: 0.9480 - val_loss: 0.0621 - val_accuracy: 0.9844 - 13s/epoch - 13s/step
# Epoch 67/200
# 1/1 - 7s - loss: 0.1403 - accuracy: 0.9480 - val_loss: 0.0553 - val_accuracy: 0.9844 - 7s/epoch - 7s/step
# Epoch 68/200
# 1/1 - 7s - loss: 0.0941 - accuracy: 0.9640 - val_loss: 0.0512 - val_accuracy: 0.9844 - 7s/epoch - 7s/step
# Epoch 69/200
# 1/1 - 7s - loss: 0.0663 - accuracy: 0.9760 - val_loss: 0.0499 - val_accuracy: 1.0000 - 7s/epoch - 7s/step
# Epoch 70/200
# 1/1 - 13s - loss: 0.1067 - accuracy: 0.9640 - val_loss: 0.0490 - val_accuracy: 1.0000 - 13s/epoch - 13s/step
# Epoch 71/200
# 1/1 - 13s - loss: 0.1404 - accuracy: 0.9600 - val_loss: 0.0469 - val_accuracy: 1.0000 - 13s/epoch - 13s/step
# Epoch 72/200
# 1/1 - 13s - loss: 0.1019 - accuracy: 0.9640 - val_loss: 0.0426 - val_accuracy: 1.0000 - 13s/epoch - 13s/step
# Epoch 73/200
# 1/1 - 13s - loss: 0.0794 - accuracy: 0.9840 - val_loss: 0.0410 - val_accuracy: 1.0000 - 13s/epoch - 13s/step
# Epoch 74/200
# 1/1 - 13s - loss: 0.1268 - accuracy: 0.9720 - val_loss: 0.0434 - val_accuracy: 0.9844 - 13s/epoch - 13s/step
# Epoch 75/200
# 1/1 - 13s - loss: 0.0985 - accuracy: 0.9720 - val_loss: 0.0448 - val_accuracy: 0.9844 - 13s/epoch - 13s/step
# Epoch 76/200
# 1/1 - 13s - loss: 0.1287 - accuracy: 0.9680 - val_loss: 0.0460 - val_accuracy: 0.9844 - 13s/epoch - 13s/step
# Epoch 77/200
# 1/1 - 13s - loss: 0.2140 - accuracy: 0.9520 - val_loss: 0.0412 - val_accuracy: 0.9844 - 13s/epoch - 13s/step
# Epoch 78/200
# 1/1 - 13s - loss: 0.0739 - accuracy: 0.9720 - val_loss: 0.0385 - val_accuracy: 1.0000 - 13s/epoch - 13s/step
# Epoch 79/200
# 1/1 - 13s - loss: 0.0752 - accuracy: 0.9720 - val_loss: 0.0379 - val_accuracy: 1.0000 - 13s/epoch - 13s/step
# Epoch 80/200
# 1/1 - 13s - loss: 0.1191 - accuracy: 0.9640 - val_loss: 0.0385 - val_accuracy: 1.0000 - 13s/epoch - 13s/step
# Epoch 81/200
# 1/1 - 13s - loss: 0.1208 - accuracy: 0.9560 - val_loss: 0.0384 - val_accuracy: 1.0000 - 13s/epoch - 13s/step
# Epoch 82/200
# 1/1 - 13s - loss: 0.0839 - accuracy: 0.9680 - val_loss: 0.0417 - val_accuracy: 0.9844 - 13s/epoch - 13s/step
# Epoch 83/200
# 1/1 - 13s - loss: 0.1269 - accuracy: 0.9600 - val_loss: 0.0487 - val_accuracy: 0.9844 - 13s/epoch - 13s/step
# Epoch 84/200
# 1/1 - 13s - loss: 0.0761 - accuracy: 0.9720 - val_loss: 0.0584 - val_accuracy: 0.9844 - 13s/epoch - 13s/step
# Epoch 85/200
# 1/1 - 13s - loss: 0.1226 - accuracy: 0.9600 - val_loss: 0.0661 - val_accuracy: 0.9844 - 13s/epoch - 13s/step
# Epoch 86/200
# 1/1 - 13s - loss: 0.0678 - accuracy: 0.9680 - val_loss: 0.0732 - val_accuracy: 0.9688 - 13s/epoch - 13s/step
# Epoch 87/200
# 1/1 - 13s - loss: 0.0821 - accuracy: 0.9640 - val_loss: 0.0717 - val_accuracy: 0.9688 - 13s/epoch - 13s/step
# Epoch 88/200
# 1/1 - 13s - loss: 0.1196 - accuracy: 0.9600 - val_loss: 0.0607 - val_accuracy: 0.9844 - 13s/epoch - 13s/step
# Epoch 89/200
# 1/1 - 15s - loss: 0.1149 - accuracy: 0.9680 - val_loss: 0.0483 - val_accuracy: 0.9844 - 15s/epoch - 15s/step
# Epoch 90/200
# 1/1 - 14s - loss: 0.1338 - accuracy: 0.9480 - val_loss: 0.0401 - val_accuracy: 0.9844 - 14s/epoch - 14s/step
# Epoch 91/200
# 1/1 - 13s - loss: 0.1576 - accuracy: 0.9520 - val_loss: 0.0414 - val_accuracy: 1.0000 - 13s/epoch - 13s/step
# Epoch 92/200
# 1/1 - 13s - loss: 0.0835 - accuracy: 0.9680 - val_loss: 0.0432 - val_accuracy: 1.0000 - 13s/epoch - 13s/step
# Epoch 93/200
# 1/1 - 7s - loss: 0.1582 - accuracy: 0.9400 - val_loss: 0.0438 - val_accuracy: 1.0000 - 7s/epoch - 7s/step
# Epoch 94/200
# 1/1 - 14s - loss: 0.1903 - accuracy: 0.9600 - val_loss: 0.0505 - val_accuracy: 0.9844 - 14s/epoch - 14s/step
# Epoch 95/200
# 1/1 - 14s - loss: 0.0998 - accuracy: 0.9720 - val_loss: 0.0631 - val_accuracy: 0.9844 - 14s/epoch - 14s/step
# Epoch 96/200
# 1/1 - 14s - loss: 0.1263 - accuracy: 0.9600 - val_loss: 0.0800 - val_accuracy: 0.9688 - 14s/epoch - 14s/step
# Epoch 97/200
# 1/1 - 14s - loss: 0.1089 - accuracy: 0.9560 - val_loss: 0.0890 - val_accuracy: 0.9688 - 14s/epoch - 14s/step
# Epoch 98/200
# 1/1 - 14s - loss: 0.0923 - accuracy: 0.9640 - val_loss: 0.0929 - val_accuracy: 0.9688 - 14s/epoch - 14s/step
# Epoch 99/200
# 1/1 - 13s - loss: 0.1186 - accuracy: 0.9600 - val_loss: 0.0843 - val_accuracy: 0.9688 - 13s/epoch - 13s/step
# Epoch 100/200
# 1/1 - 7s - loss: 0.1532 - accuracy: 0.9440 - val_loss: 0.0708 - val_accuracy: 0.9688 - 7s/epoch - 7s/step
# Epoch 101/200
# 1/1 - 13s - loss: 0.0705 - accuracy: 0.9760 - val_loss: 0.0575 - val_accuracy: 0.9844 - 13s/epoch - 13s/step
# Epoch 102/200
# 1/1 - 13s - loss: 0.1242 - accuracy: 0.9640 - val_loss: 0.0472 - val_accuracy: 0.9844 - 13s/epoch - 13s/step
# Epoch 103/200
# 1/1 - 13s - loss: 0.0686 - accuracy: 0.9800 - val_loss: 0.0421 - val_accuracy: 1.0000 - 13s/epoch - 13s/step
# Epoch 104/200
# 1/1 - 13s - loss: 0.1222 - accuracy: 0.9680 - val_loss: 0.0410 - val_accuracy: 1.0000 - 13s/epoch - 13s/step
# Epoch 105/200
# 1/1 - 13s - loss: 0.1351 - accuracy: 0.9520 - val_loss: 0.0383 - val_accuracy: 1.0000 - 13s/epoch - 13s/step
# Epoch 106/200
# 1/1 - 13s - loss: 0.0969 - accuracy: 0.9680 - val_loss: 0.0341 - val_accuracy: 1.0000 - 13s/epoch - 13s/step
# Epoch 107/200
# 1/1 - 13s - loss: 0.1230 - accuracy: 0.9680 - val_loss: 0.0315 - val_accuracy: 1.0000 - 13s/epoch - 13s/step
# Epoch 108/200
# 1/1 - 14s - loss: 0.0710 - accuracy: 0.9800 - val_loss: 0.0305 - val_accuracy: 1.0000 - 14s/epoch - 14s/step
# Epoch 109/200
# 1/1 - 13s - loss: 0.1205 - accuracy: 0.9640 - val_loss: 0.0315 - val_accuracy: 1.0000 - 13s/epoch - 13s/step
# Epoch 110/200
# 1/1 - 13s - loss: 0.0474 - accuracy: 0.9800 - val_loss: 0.0353 - val_accuracy: 0.9844 - 13s/epoch - 13s/step
# Epoch 111/200
# 1/1 - 13s - loss: 0.1197 - accuracy: 0.9600 - val_loss: 0.0421 - val_accuracy: 0.9844 - 13s/epoch - 13s/step
# Epoch 112/200
# 1/1 - 14s - loss: 0.0767 - accuracy: 0.9720 - val_loss: 0.0475 - val_accuracy: 0.9688 - 14s/epoch - 14s/step
# Epoch 113/200
# 1/1 - 14s - loss: 0.1268 - accuracy: 0.9640 - val_loss: 0.0502 - val_accuracy: 0.9688 - 14s/epoch - 14s/step
# Epoch 114/200
# 1/1 - 14s - loss: 0.0627 - accuracy: 0.9720 - val_loss: 0.0494 - val_accuracy: 0.9688 - 14s/epoch - 14s/step
# Epoch 115/200
# 1/1 - 14s - loss: 0.1059 - accuracy: 0.9600 - val_loss: 0.0435 - val_accuracy: 0.9688 - 14s/epoch - 14s/step
# Epoch 116/200
# 1/1 - 14s - loss: 0.1994 - accuracy: 0.9600 - val_loss: 0.0368 - val_accuracy: 0.9844 - 14s/epoch - 14s/step
# Epoch 117/200
# 1/1 - 14s - loss: 0.0711 - accuracy: 0.9680 - val_loss: 0.0338 - val_accuracy: 1.0000 - 14s/epoch - 14s/step
# Epoch 118/200
# 1/1 - 13s - loss: 0.0831 - accuracy: 0.9720 - val_loss: 0.0332 - val_accuracy: 1.0000 - 13s/epoch - 13s/step
# Epoch 119/200
# 1/1 - 13s - loss: 0.1450 - accuracy: 0.9440 - val_loss: 0.0352 - val_accuracy: 1.0000 - 13s/epoch - 13s/step
# Epoch 120/200
# 1/1 - 13s - loss: 0.0547 - accuracy: 0.9840 - val_loss: 0.0364 - val_accuracy: 1.0000 - 13s/epoch - 13s/step
# Epoch 121/200
# 1/1 - 13s - loss: 0.0781 - accuracy: 0.9840 - val_loss: 0.0378 - val_accuracy: 1.0000 - 13s/epoch - 13s/step
# Epoch 122/200
# 1/1 - 13s - loss: 0.0879 - accuracy: 0.9640 - val_loss: 0.0410 - val_accuracy: 1.0000 - 13s/epoch - 13s/step
# Epoch 123/200
# 1/1 - 13s - loss: 0.0746 - accuracy: 0.9800 - val_loss: 0.0460 - val_accuracy: 0.9688 - 13s/epoch - 13s/step
# Epoch 124/200
# 1/1 - 13s - loss: 0.1149 - accuracy: 0.9560 - val_loss: 0.0507 - val_accuracy: 0.9688 - 13s/epoch - 13s/step
# Epoch 125/200
# 1/1 - 12s - loss: 0.1127 - accuracy: 0.9600 - val_loss: 0.0520 - val_accuracy: 0.9688 - 12s/epoch - 12s/step
# Epoch 126/200
# 1/1 - 13s - loss: 0.0934 - accuracy: 0.9760 - val_loss: 0.0500 - val_accuracy: 0.9688 - 13s/epoch - 13s/step
# Epoch 127/200
# 1/1 - 13s - loss: 0.0947 - accuracy: 0.9560 - val_loss: 0.0448 - val_accuracy: 0.9688 - 13s/epoch - 13s/step
# Epoch 128/200
# 1/1 - 13s - loss: 0.0616 - accuracy: 0.9800 - val_loss: 0.0394 - val_accuracy: 0.9844 - 13s/epoch - 13s/step
# Epoch 129/200
# 1/1 - 12s - loss: 0.0654 - accuracy: 0.9800 - val_loss: 0.0340 - val_accuracy: 1.0000 - 12s/epoch - 12s/step
# Epoch 130/200
# 1/1 - 7s - loss: 0.0793 - accuracy: 0.9680 - val_loss: 0.0300 - val_accuracy: 1.0000 - 7s/epoch - 7s/step
# Epoch 131/200
# 1/1 - 12s - loss: 0.1031 - accuracy: 0.9560 - val_loss: 0.0289 - val_accuracy: 1.0000 - 12s/epoch - 12s/step
# Epoch 132/200
# 1/1 - 7s - loss: 0.0919 - accuracy: 0.9680 - val_loss: 0.0282 - val_accuracy: 1.0000 - 7s/epoch - 7s/step
# Epoch 133/200
# 1/1 - 13s - loss: 0.0685 - accuracy: 0.9760 - val_loss: 0.0267 - val_accuracy: 1.0000 - 13s/epoch - 13s/step
# Epoch 134/200
# 1/1 - 13s - loss: 0.1128 - accuracy: 0.9800 - val_loss: 0.0249 - val_accuracy: 1.0000 - 13s/epoch - 13s/step
# Epoch 135/200
# 1/1 - 13s - loss: 0.0996 - accuracy: 0.9720 - val_loss: 0.0244 - val_accuracy: 1.0000 - 13s/epoch - 13s/step
# Epoch 136/200
# 1/1 - 13s - loss: 0.1291 - accuracy: 0.9640 - val_loss: 0.0247 - val_accuracy: 1.0000 - 13s/epoch - 13s/step
# Epoch 137/200
# 1/1 - 13s - loss: 0.0683 - accuracy: 0.9720 - val_loss: 0.0258 - val_accuracy: 1.0000 - 13s/epoch - 13s/step
# Epoch 138/200
# 1/1 - 13s - loss: 0.0355 - accuracy: 0.9920 - val_loss: 0.0273 - val_accuracy: 1.0000 - 13s/epoch - 13s/step
# Epoch 139/200
# 1/1 - 13s - loss: 0.0725 - accuracy: 0.9800 - val_loss: 0.0300 - val_accuracy: 1.0000 - 13s/epoch - 13s/step
# Epoch 140/200
# 1/1 - 13s - loss: 0.0741 - accuracy: 0.9720 - val_loss: 0.0331 - val_accuracy: 0.9844 - 13s/epoch - 13s/step
# Epoch 141/200
# 1/1 - 13s - loss: 0.0629 - accuracy: 0.9800 - val_loss: 0.0348 - val_accuracy: 0.9844 - 13s/epoch - 13s/step
# Epoch 142/200
# 1/1 - 13s - loss: 0.0480 - accuracy: 0.9760 - val_loss: 0.0363 - val_accuracy: 0.9844 - 13s/epoch - 13s/step
# Epoch 143/200
# 1/1 - 13s - loss: 0.0501 - accuracy: 0.9840 - val_loss: 0.0351 - val_accuracy: 0.9844 - 13s/epoch - 13s/step
# Epoch 144/200
# 1/1 - 13s - loss: 0.0826 - accuracy: 0.9640 - val_loss: 0.0307 - val_accuracy: 0.9844 - 13s/epoch - 13s/step
# Epoch 145/200
# 1/1 - 13s - loss: 0.1010 - accuracy: 0.9600 - val_loss: 0.0217 - val_accuracy: 1.0000 - 13s/epoch - 13s/step
# Epoch 146/200
# 1/1 - 13s - loss: 0.0452 - accuracy: 0.9800 - val_loss: 0.0163 - val_accuracy: 1.0000 - 13s/epoch - 13s/step
# Epoch 147/200
# 1/1 - 13s - loss: 0.0525 - accuracy: 0.9760 - val_loss: 0.0141 - val_accuracy: 1.0000 - 13s/epoch - 13s/step
# Epoch 148/200
# 1/1 - 13s - loss: 0.0776 - accuracy: 0.9720 - val_loss: 0.0129 - val_accuracy: 1.0000 - 13s/epoch - 13s/step
# Epoch 149/200
# 1/1 - 13s - loss: 0.0609 - accuracy: 0.9600 - val_loss: 0.0119 - val_accuracy: 1.0000 - 13s/epoch - 13s/step
# Epoch 150/200
# 1/1 - 7s - loss: 0.0990 - accuracy: 0.9680 - val_loss: 0.0119 - val_accuracy: 1.0000 - 7s/epoch - 7s/step
# Epoch 151/200
# 1/1 - 13s - loss: 0.0780 - accuracy: 0.9680 - val_loss: 0.0137 - val_accuracy: 1.0000 - 13s/epoch - 13s/step
# Epoch 152/200
# 1/1 - 13s - loss: 0.0739 - accuracy: 0.9640 - val_loss: 0.0159 - val_accuracy: 1.0000 - 13s/epoch - 13s/step
# Epoch 153/200
# 1/1 - 13s - loss: 0.0464 - accuracy: 0.9920 - val_loss: 0.0192 - val_accuracy: 1.0000 - 13s/epoch - 13s/step
# Epoch 154/200
# 1/1 - 13s - loss: 0.0798 - accuracy: 0.9760 - val_loss: 0.0219 - val_accuracy: 1.0000 - 13s/epoch - 13s/step
# Epoch 155/200
# 1/1 - 13s - loss: 0.0323 - accuracy: 0.9920 - val_loss: 0.0232 - val_accuracy: 1.0000 - 13s/epoch - 13s/step
# Epoch 156/200
# 1/1 - 13s - loss: 0.0892 - accuracy: 0.9680 - val_loss: 0.0253 - val_accuracy: 1.0000 - 13s/epoch - 13s/step
# Epoch 157/200
# 1/1 - 13s - loss: 0.0351 - accuracy: 0.9840 - val_loss: 0.0241 - val_accuracy: 1.0000 - 13s/epoch - 13s/step
# Epoch 158/200
# 1/1 - 13s - loss: 0.0403 - accuracy: 0.9840 - val_loss: 0.0227 - val_accuracy: 1.0000 - 13s/epoch - 13s/step
# Epoch 159/200
# 1/1 - 13s - loss: 0.0554 - accuracy: 0.9760 - val_loss: 0.0197 - val_accuracy: 1.0000 - 13s/epoch - 13s/step
# Epoch 160/200
# 1/1 - 13s - loss: 0.1152 - accuracy: 0.9520 - val_loss: 0.0167 - val_accuracy: 1.0000 - 13s/epoch - 13s/step
# Epoch 161/200
# 1/1 - 12s - loss: 0.0265 - accuracy: 0.9880 - val_loss: 0.0148 - val_accuracy: 1.0000 - 12s/epoch - 12s/step
# Epoch 162/200
# 1/1 - 7s - loss: 0.0367 - accuracy: 0.9840 - val_loss: 0.0137 - val_accuracy: 1.0000 - 7s/epoch - 7s/step
# Epoch 163/200
# 1/1 - 7s - loss: 0.0960 - accuracy: 0.9760 - val_loss: 0.0131 - val_accuracy: 1.0000 - 7s/epoch - 7s/step
# Epoch 164/200
# 1/1 - 12s - loss: 0.0423 - accuracy: 0.9840 - val_loss: 0.0127 - val_accuracy: 1.0000 - 12s/epoch - 12s/step
# Epoch 165/200
# 1/1 - 13s - loss: 0.0965 - accuracy: 0.9600 - val_loss: 0.0125 - val_accuracy: 1.0000 - 13s/epoch - 13s/step
# Epoch 166/200
# 1/1 - 13s - loss: 0.0489 - accuracy: 0.9800 - val_loss: 0.0121 - val_accuracy: 1.0000 - 13s/epoch - 13s/step
# Epoch 167/200
# 1/1 - 13s - loss: 0.1951 - accuracy: 0.9680 - val_loss: 0.0131 - val_accuracy: 1.0000 - 13s/epoch - 13s/step
# Epoch 168/200
# 1/1 - 13s - loss: 0.0468 - accuracy: 0.9840 - val_loss: 0.0139 - val_accuracy: 1.0000 - 13s/epoch - 13s/step
# Epoch 169/200
# 1/1 - 14s - loss: 0.0352 - accuracy: 0.9920 - val_loss: 0.0147 - val_accuracy: 1.0000 - 14s/epoch - 14s/step
# Epoch 170/200
# 1/1 - 14s - loss: 0.0946 - accuracy: 0.9640 - val_loss: 0.0167 - val_accuracy: 1.0000 - 14s/epoch - 14s/step
# Epoch 171/200
# 1/1 - 14s - loss: 0.0445 - accuracy: 0.9840 - val_loss: 0.0194 - val_accuracy: 1.0000 - 14s/epoch - 14s/step
# Epoch 172/200
# 1/1 - 14s - loss: 0.0595 - accuracy: 0.9800 - val_loss: 0.0215 - val_accuracy: 1.0000 - 14s/epoch - 14s/step
# Epoch 173/200
# 1/1 - 14s - loss: 0.0420 - accuracy: 0.9920 - val_loss: 0.0228 - val_accuracy: 1.0000 - 14s/epoch - 14s/step
# Epoch 174/200
# 1/1 - 13s - loss: 0.1095 - accuracy: 0.9480 - val_loss: 0.0233 - val_accuracy: 1.0000 - 13s/epoch - 13s/step
# Epoch 175/200
# 1/1 - 14s - loss: 0.1210 - accuracy: 0.9600 - val_loss: 0.0228 - val_accuracy: 1.0000 - 14s/epoch - 14s/step
# Epoch 176/200
# 1/1 - 14s - loss: 0.0650 - accuracy: 0.9840 - val_loss: 0.0225 - val_accuracy: 1.0000 - 14s/epoch - 14s/step
# Epoch 177/200
# 1/1 - 14s - loss: 0.0211 - accuracy: 0.9960 - val_loss: 0.0223 - val_accuracy: 1.0000 - 14s/epoch - 14s/step
# Epoch 178/200
# 1/1 - 14s - loss: 0.0473 - accuracy: 0.9880 - val_loss: 0.0219 - val_accuracy: 1.0000 - 14s/epoch - 14s/step
# Epoch 179/200
# 1/1 - 14s - loss: 0.0762 - accuracy: 0.9680 - val_loss: 0.0222 - val_accuracy: 1.0000 - 14s/epoch - 14s/step
# Epoch 180/200
# 1/1 - 15s - loss: 0.0742 - accuracy: 0.9800 - val_loss: 0.0228 - val_accuracy: 1.0000 - 15s/epoch - 15s/step
# Epoch 181/200
# 1/1 - 14s - loss: 0.0801 - accuracy: 0.9680 - val_loss: 0.0236 - val_accuracy: 1.0000 - 14s/epoch - 14s/step
# Epoch 182/200
# 1/1 - 13s - loss: 0.0493 - accuracy: 0.9800 - val_loss: 0.0247 - val_accuracy: 1.0000 - 13s/epoch - 13s/step
# Epoch 183/200
# 1/1 - 13s - loss: 0.0676 - accuracy: 0.9800 - val_loss: 0.0266 - val_accuracy: 0.9844 - 13s/epoch - 13s/step
# Epoch 184/200
# 1/1 - 7s - loss: 0.0513 - accuracy: 0.9840 - val_loss: 0.0300 - val_accuracy: 0.9844 - 7s/epoch - 7s/step
# Epoch 185/200
# 1/1 - 13s - loss: 0.0665 - accuracy: 0.9840 - val_loss: 0.0337 - val_accuracy: 0.9844 - 13s/epoch - 13s/step
# Epoch 186/200
# 1/1 - 13s - loss: 0.0426 - accuracy: 0.9760 - val_loss: 0.0359 - val_accuracy: 0.9844 - 13s/epoch - 13s/step
# Epoch 187/200
# 1/1 - 13s - loss: 0.0680 - accuracy: 0.9840 - val_loss: 0.0373 - val_accuracy: 0.9844 - 13s/epoch - 13s/step
# Epoch 188/200
# 1/1 - 13s - loss: 0.0614 - accuracy: 0.9800 - val_loss: 0.0340 - val_accuracy: 0.9844 - 13s/epoch - 13s/step
# Epoch 189/200
# 1/1 - 13s - loss: 0.0729 - accuracy: 0.9840 - val_loss: 0.0298 - val_accuracy: 0.9844 - 13s/epoch - 13s/step
# Epoch 190/200
# 1/1 - 13s - loss: 0.1376 - accuracy: 0.9720 - val_loss: 0.0238 - val_accuracy: 0.9844 - 13s/epoch - 13s/step
# Epoch 191/200
# 1/1 - 13s - loss: 0.0766 - accuracy: 0.9720 - val_loss: 0.0195 - val_accuracy: 1.0000 - 13s/epoch - 13s/step
# Epoch 192/200
# 1/1 - 13s - loss: 0.0383 - accuracy: 0.9880 - val_loss: 0.0173 - val_accuracy: 1.0000 - 13s/epoch - 13s/step
# Epoch 193/200
# 1/1 - 14s - loss: 0.0529 - accuracy: 0.9720 - val_loss: 0.0163 - val_accuracy: 1.0000 - 14s/epoch - 14s/step
# Epoch 194/200
# 1/1 - 14s - loss: 0.0548 - accuracy: 0.9760 - val_loss: 0.0160 - val_accuracy: 1.0000 - 14s/epoch - 14s/step
# Epoch 195/200
# 1/1 - 14s - loss: 0.0301 - accuracy: 0.9960 - val_loss: 0.0158 - val_accuracy: 1.0000 - 14s/epoch - 14s/step
# Epoch 196/200
# 1/1 - 14s - loss: 0.0810 - accuracy: 0.9640 - val_loss: 0.0159 - val_accuracy: 1.0000 - 14s/epoch - 14s/step
# Epoch 197/200
# 1/1 - 8s - loss: 0.0761 - accuracy: 0.9720 - val_loss: 0.0168 - val_accuracy: 1.0000 - 8s/epoch - 8s/step
# Epoch 198/200
# 1/1 - 14s - loss: 0.0398 - accuracy: 0.9840 - val_loss: 0.0177 - val_accuracy: 1.0000 - 14s/epoch - 14s/step
# Epoch 199/200
# 1/1 - 14s - loss: 0.0472 - accuracy: 0.9880 - val_loss: 0.0176 - val_accuracy: 1.0000 - 14s/epoch - 14s/step
# Epoch 200/200
# 1/1 - 15s - loss: 0.0345 - accuracy: 0.9880 - val_loss: 0.0168 - val_accuracy: 1.0000 - 15s/epoch - 15s/step

# %%
### TRAINING ACCURACIES 
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix

# Prediction of testing dataset
pred_1 = np.argmax(model.predict(y_test[0]), axis=-1)

# Comparison with ground-truth data
print('Val accuracy', accuracy_score(y_test[1], pred_1))
print(confusion_matrix(y_test[1], pred_1))
# Out:
# Val accuracy 1.0
# [[32  0]
#  [ 0 32]]

# %%
### SAVING OF MODEL ARCHITECTURE AND PARAMETERS
model.save('determination_date_M')
# Out:
# INFO:tensorflow:Assets written to: determination_date_M_v4\assets
